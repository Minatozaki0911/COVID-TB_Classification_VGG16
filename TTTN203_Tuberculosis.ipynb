# %% [markdown]
# <a href="https://colab.research.google.com/github/Minatozaki0911/summerIntern203/blob/master/TTTN203_Tuberculosis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q kaggle
from google.colab import files
print("Please input your kaggle.json API Token")
files.upload()
# !mkdir ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json
# Out:
#      <input type="file" id="files-1d5599bd-6940-444e-b3d9-5afa6b967e06" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1d5599bd-6940-444e-b3d9-5afa6b967e06">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle.json
# Please input your kaggle.json API Token

# %%
ans = input("Do you want to retrain model ? (y/n)\n")
retrain = 0
if ans == 'y':
  retrain = 1
else: 
  retrain = 0
  input('Have you uploaded the model zip file ?\nPlease check the path to your model before continue (OK)\n ')
  # !mkdir -p '/content/TB_Model'
  # !unzip '/content/TB_Model.zip' -d '/content/TB_Model'
  print('Completed')
# Out:
# Do you want to retrain model ? (y/n)
# y

# %%
# !kaggle datasets download -d raddar/tuberculosis-chest-xrays-shenzhen
# Out:
# Downloading tuberculosis-chest-xrays-shenzhen.zip to /content
# 100% 3.50G/3.51G [00:59<00:00, 39.0MB/s]
# 100% 3.51G/3.51G [00:59<00:00, 63.4MB/s]

# %%
# !unzip '/content/tuberculosis-chest-xrays-shenzhen.zip'
# Out:
# Archive:  /content/tuberculosis-chest-xrays-shenzhen.zip
#   inflating: images/images/CHNCXR_0001_0.png
#   inflating: images/images/CHNCXR_0002_0.png
#   inflating: images/images/CHNCXR_0003_0.png
#   inflating: images/images/CHNCXR_0004_0.png
#   inflating: images/images/CHNCXR_0005_0.png
#   inflating: images/images/CHNCXR_0006_0.png
#   inflating: images/images/CHNCXR_0007_0.png
#   inflating: images/images/CHNCXR_0008_0.png
#   inflating: images/images/CHNCXR_0009_0.png
#   inflating: images/images/CHNCXR_0010_0.png
#   inflating: images/images/CHNCXR_0011_0.png
#   inflating: images/images/CHNCXR_0012_0.png
#   inflating: images/images/CHNCXR_0013_0.png
#   inflating: images/images/CHNCXR_0014_0.png
#   inflating: images/images/CHNCXR_0015_0.png
#   inflating: images/images/CHNCXR_0016_0.png
#   inflating: images/images/CHNCXR_0017_0.png
#   inflating: images/images/CHNCXR_0018_0.png
#   inflating: images/images/CHNCXR_0019_0.png
#   inflating: images/images/CHNCXR_0020_0.png
#   inflating: images/images/CHNCXR_0021_0.png
#   inflating: images/images/CHNCXR_0022_0.png
#   inflating: images/images/CHNCXR_0023_0.png
#   inflating: images/images/CHNCXR_0024_0.png
#   inflating: images/images/CHNCXR_0025_0.png
#   inflating: images/images/CHNCXR_0026_0.png
#   inflating: images/images/CHNCXR_0027_0.png
#   inflating: images/images/CHNCXR_0028_0.png
#   inflating: images/images/CHNCXR_0029_0.png
#   inflating: images/images/CHNCXR_0030_0.png
#   inflating: images/images/CHNCXR_0031_0.png
#   inflating: images/images/CHNCXR_0032_0.png
#   inflating: images/images/CHNCXR_0033_0.png
#   inflating: images/images/CHNCXR_0034_0.png
#   inflating: images/images/CHNCXR_0035_0.png
#   inflating: images/images/CHNCXR_0036_0.png
#   inflating: images/images/CHNCXR_0037_0.png
#   inflating: images/images/CHNCXR_0038_0.png
#   inflating: images/images/CHNCXR_0039_0.png
#   inflating: images/images/CHNCXR_0040_0.png
#   inflating: images/images/CHNCXR_0041_0.png
#   inflating: images/images/CHNCXR_0042_0.png
#   inflating: images/images/CHNCXR_0043_0.png
#   inflating: images/images/CHNCXR_0044_0.png
#   inflating: images/images/CHNCXR_0045_0.png
#   inflating: images/images/CHNCXR_0046_0.png
#   inflating: images/images/CHNCXR_0047_0.png
#   inflating: images/images/CHNCXR_0048_0.png
#   inflating: images/images/CHNCXR_0049_0.png
#   inflating: images/images/CHNCXR_0050_0.png
#   inflating: images/images/CHNCXR_0051_0.png
#   inflating: images/images/CHNCXR_0052_0.png
#   inflating: images/images/CHNCXR_0053_0.png
#   inflating: images/images/CHNCXR_0054_0.png
#   inflating: images/images/CHNCXR_0055_0.png
#   inflating: images/images/CHNCXR_0056_0.png
#   inflating: images/images/CHNCXR_0057_0.png
#   inflating: images/images/CHNCXR_0058_0.png
#   inflating: images/images/CHNCXR_0059_0.png
#   inflating: images/images/CHNCXR_0060_0.png
#   inflating: images/images/CHNCXR_0061_0.png
#   inflating: images/images/CHNCXR_0062_0.png
#   inflating: images/images/CHNCXR_0063_0.png
#   inflating: images/images/CHNCXR_0064_0.png
#   inflating: images/images/CHNCXR_0065_0.png
#   inflating: images/images/CHNCXR_0066_0.png
#   inflating: images/images/CHNCXR_0067_0.png
#   inflating: images/images/CHNCXR_0068_0.png
#   inflating: images/images/CHNCXR_0069_0.png
#   inflating: images/images/CHNCXR_0070_0.png
#   inflating: images/images/CHNCXR_0071_0.png
#   inflating: images/images/CHNCXR_0072_0.png
#   inflating: images/images/CHNCXR_0073_0.png
#   inflating: images/images/CHNCXR_0074_0.png
#   inflating: images/images/CHNCXR_0075_0.png
#   inflating: images/images/CHNCXR_0076_0.png
#   inflating: images/images/CHNCXR_0077_0.png
#   inflating: images/images/CHNCXR_0078_0.png
#   inflating: images/images/CHNCXR_0079_0.png
#   inflating: images/images/CHNCXR_0080_0.png
#   inflating: images/images/CHNCXR_0081_0.png
#   inflating: images/images/CHNCXR_0082_0.png
#   inflating: images/images/CHNCXR_0083_0.png
#   inflating: images/images/CHNCXR_0084_0.png
#   inflating: images/images/CHNCXR_0085_0.png
#   inflating: images/images/CHNCXR_0086_0.png
#   inflating: images/images/CHNCXR_0087_0.png
#   inflating: images/images/CHNCXR_0088_0.png
#   inflating: images/images/CHNCXR_0089_0.png
#   inflating: images/images/CHNCXR_0090_0.png
#   inflating: images/images/CHNCXR_0091_0.png
#   inflating: images/images/CHNCXR_0092_0.png
#   inflating: images/images/CHNCXR_0093_0.png
#   inflating: images/images/CHNCXR_0094_0.png
#   inflating: images/images/CHNCXR_0095_0.png
#   inflating: images/images/CHNCXR_0096_0.png
#   inflating: images/images/CHNCXR_0097_0.png
#   inflating: images/images/CHNCXR_0098_0.png
#   inflating: images/images/CHNCXR_0099_0.png
#   inflating: images/images/CHNCXR_0100_0.png
#   inflating: images/images/CHNCXR_0101_0.png
#   inflating: images/images/CHNCXR_0102_0.png
#   inflating: images/images/CHNCXR_0103_0.png
#   inflating: images/images/CHNCXR_0104_0.png
#   inflating: images/images/CHNCXR_0105_0.png
#   inflating: images/images/CHNCXR_0106_0.png
#   inflating: images/images/CHNCXR_0107_0.png
#   inflating: images/images/CHNCXR_0108_0.png
#   inflating: images/images/CHNCXR_0109_0.png
#   inflating: images/images/CHNCXR_0110_0.png
#   inflating: images/images/CHNCXR_0111_0.png
#   inflating: images/images/CHNCXR_0112_0.png
#   inflating: images/images/CHNCXR_0113_0.png
#   inflating: images/images/CHNCXR_0114_0.png
#   inflating: images/images/CHNCXR_0115_0.png
#   inflating: images/images/CHNCXR_0116_0.png
#   inflating: images/images/CHNCXR_0117_0.png
#   inflating: images/images/CHNCXR_0118_0.png
#   inflating: images/images/CHNCXR_0119_0.png
#   inflating: images/images/CHNCXR_0120_0.png
#   inflating: images/images/CHNCXR_0121_0.png
#   inflating: images/images/CHNCXR_0122_0.png
#   inflating: images/images/CHNCXR_0123_0.png
#   inflating: images/images/CHNCXR_0124_0.png
#   inflating: images/images/CHNCXR_0125_0.png
#   inflating: images/images/CHNCXR_0126_0.png
#   inflating: images/images/CHNCXR_0127_0.png
#   inflating: images/images/CHNCXR_0128_0.png
#   inflating: images/images/CHNCXR_0129_0.png
#   inflating: images/images/CHNCXR_0130_0.png
#   inflating: images/images/CHNCXR_0131_0.png
#   inflating: images/images/CHNCXR_0132_0.png
#   inflating: images/images/CHNCXR_0133_0.png
#   inflating: images/images/CHNCXR_0134_0.png
#   inflating: images/images/CHNCXR_0135_0.png
#   inflating: images/images/CHNCXR_0136_0.png
#   inflating: images/images/CHNCXR_0137_0.png
#   inflating: images/images/CHNCXR_0138_0.png
#   inflating: images/images/CHNCXR_0139_0.png
#   inflating: images/images/CHNCXR_0140_0.png
#   inflating: images/images/CHNCXR_0141_0.png
#   inflating: images/images/CHNCXR_0142_0.png
#   inflating: images/images/CHNCXR_0143_0.png
#   inflating: images/images/CHNCXR_0144_0.png
#   inflating: images/images/CHNCXR_0145_0.png
#   inflating: images/images/CHNCXR_0146_0.png
#   inflating: images/images/CHNCXR_0147_0.png
#   inflating: images/images/CHNCXR_0148_0.png
#   inflating: images/images/CHNCXR_0149_0.png
#   inflating: images/images/CHNCXR_0150_0.png
#   inflating: images/images/CHNCXR_0151_0.png
#   inflating: images/images/CHNCXR_0152_0.png
#   inflating: images/images/CHNCXR_0153_0.png
#   inflating: images/images/CHNCXR_0154_0.png
#   inflating: images/images/CHNCXR_0155_0.png
#   inflating: images/images/CHNCXR_0156_0.png
#   inflating: images/images/CHNCXR_0157_0.png
#   inflating: images/images/CHNCXR_0158_0.png
#   inflating: images/images/CHNCXR_0159_0.png
#   inflating: images/images/CHNCXR_0160_0.png
#   inflating: images/images/CHNCXR_0161_0.png
#   inflating: images/images/CHNCXR_0162_0.png
#   inflating: images/images/CHNCXR_0163_0.png
#   inflating: images/images/CHNCXR_0164_0.png
#   inflating: images/images/CHNCXR_0165_0.png
#   inflating: images/images/CHNCXR_0166_0.png
#   inflating: images/images/CHNCXR_0167_0.png
#   inflating: images/images/CHNCXR_0168_0.png
#   inflating: images/images/CHNCXR_0169_0.png
#   inflating: images/images/CHNCXR_0170_0.png
#   inflating: images/images/CHNCXR_0171_0.png
#   inflating: images/images/CHNCXR_0172_0.png
#   inflating: images/images/CHNCXR_0173_0.png
#   inflating: images/images/CHNCXR_0174_0.png
#   inflating: images/images/CHNCXR_0175_0.png
#   inflating: images/images/CHNCXR_0176_0.png
#   inflating: images/images/CHNCXR_0177_0.png
#   inflating: images/images/CHNCXR_0178_0.png
#   inflating: images/images/CHNCXR_0179_0.png
#   inflating: images/images/CHNCXR_0180_0.png
#   inflating: images/images/CHNCXR_0181_0.png
#   inflating: images/images/CHNCXR_0182_0.png
#   inflating: images/images/CHNCXR_0183_0.png
#   inflating: images/images/CHNCXR_0184_0.png
#   inflating: images/images/CHNCXR_0185_0.png
#   inflating: images/images/CHNCXR_0186_0.png
#   inflating: images/images/CHNCXR_0187_0.png
#   inflating: images/images/CHNCXR_0188_0.png
#   inflating: images/images/CHNCXR_0189_0.png
#   inflating: images/images/CHNCXR_0190_0.png
#   inflating: images/images/CHNCXR_0191_0.png
#   inflating: images/images/CHNCXR_0192_0.png
#   inflating: images/images/CHNCXR_0193_0.png
#   inflating: images/images/CHNCXR_0194_0.png
#   inflating: images/images/CHNCXR_0195_0.png
#   inflating: images/images/CHNCXR_0196_0.png
#   inflating: images/images/CHNCXR_0197_0.png
#   inflating: images/images/CHNCXR_0198_0.png
#   inflating: images/images/CHNCXR_0199_0.png
#   inflating: images/images/CHNCXR_0200_0.png
#   inflating: images/images/CHNCXR_0201_0.png
#   inflating: images/images/CHNCXR_0202_0.png
#   inflating: images/images/CHNCXR_0203_0.png
#   inflating: images/images/CHNCXR_0204_0.png
#   inflating: images/images/CHNCXR_0205_0.png
#   inflating: images/images/CHNCXR_0206_0.png
#   inflating: images/images/CHNCXR_0207_0.png
#   inflating: images/images/CHNCXR_0208_0.png
#   inflating: images/images/CHNCXR_0209_0.png
#   inflating: images/images/CHNCXR_0210_0.png
#   inflating: images/images/CHNCXR_0211_0.png
#   inflating: images/images/CHNCXR_0212_0.png
#   inflating: images/images/CHNCXR_0213_0.png
#   inflating: images/images/CHNCXR_0214_0.png
#   inflating: images/images/CHNCXR_0215_0.png
#   inflating: images/images/CHNCXR_0216_0.png
#   inflating: images/images/CHNCXR_0217_0.png
#   inflating: images/images/CHNCXR_0218_0.png
#   inflating: images/images/CHNCXR_0219_0.png
#   inflating: images/images/CHNCXR_0220_0.png
#   inflating: images/images/CHNCXR_0221_0.png
#   inflating: images/images/CHNCXR_0222_0.png
#   inflating: images/images/CHNCXR_0223_0.png
#   inflating: images/images/CHNCXR_0224_0.png
#   inflating: images/images/CHNCXR_0225_0.png
#   inflating: images/images/CHNCXR_0226_0.png
#   inflating: images/images/CHNCXR_0227_0.png
#   inflating: images/images/CHNCXR_0228_0.png
#   inflating: images/images/CHNCXR_0229_0.png
#   inflating: images/images/CHNCXR_0230_0.png
#   inflating: images/images/CHNCXR_0231_0.png
#   inflating: images/images/CHNCXR_0232_0.png
#   inflating: images/images/CHNCXR_0233_0.png
#   inflating: images/images/CHNCXR_0234_0.png
#   inflating: images/images/CHNCXR_0235_0.png
#   inflating: images/images/CHNCXR_0236_0.png
#   inflating: images/images/CHNCXR_0237_0.png
#   inflating: images/images/CHNCXR_0238_0.png
#   inflating: images/images/CHNCXR_0239_0.png
#   inflating: images/images/CHNCXR_0240_0.png
#   inflating: images/images/CHNCXR_0241_0.png
#   inflating: images/images/CHNCXR_0242_0.png
#   inflating: images/images/CHNCXR_0243_0.png
#   inflating: images/images/CHNCXR_0244_0.png
#   inflating: images/images/CHNCXR_0245_0.png
#   inflating: images/images/CHNCXR_0246_0.png
#   inflating: images/images/CHNCXR_0247_0.png
#   inflating: images/images/CHNCXR_0248_0.png
#   inflating: images/images/CHNCXR_0249_0.png
#   inflating: images/images/CHNCXR_0250_0.png
#   inflating: images/images/CHNCXR_0251_0.png
#   inflating: images/images/CHNCXR_0252_0.png
#   inflating: images/images/CHNCXR_0253_0.png
#   inflating: images/images/CHNCXR_0254_0.png
#   inflating: images/images/CHNCXR_0255_0.png
#   inflating: images/images/CHNCXR_0256_0.png
#   inflating: images/images/CHNCXR_0257_0.png
#   inflating: images/images/CHNCXR_0258_0.png
#   inflating: images/images/CHNCXR_0259_0.png
#   inflating: images/images/CHNCXR_0260_0.png
#   inflating: images/images/CHNCXR_0261_0.png
#   inflating: images/images/CHNCXR_0262_0.png
#   inflating: images/images/CHNCXR_0263_0.png
#   inflating: images/images/CHNCXR_0264_0.png
#   inflating: images/images/CHNCXR_0265_0.png
#   inflating: images/images/CHNCXR_0266_0.png
#   inflating: images/images/CHNCXR_0267_0.png
#   inflating: images/images/CHNCXR_0268_0.png
#   inflating: images/images/CHNCXR_0269_0.png
#   inflating: images/images/CHNCXR_0270_0.png
#   inflating: images/images/CHNCXR_0271_0.png
#   inflating: images/images/CHNCXR_0272_0.png
#   inflating: images/images/CHNCXR_0273_0.png
#   inflating: images/images/CHNCXR_0274_0.png
#   inflating: images/images/CHNCXR_0275_0.png
#   inflating: images/images/CHNCXR_0276_0.png
#   inflating: images/images/CHNCXR_0277_0.png
#   inflating: images/images/CHNCXR_0278_0.png
#   inflating: images/images/CHNCXR_0279_0.png
#   inflating: images/images/CHNCXR_0280_0.png
#   inflating: images/images/CHNCXR_0281_0.png
#   inflating: images/images/CHNCXR_0282_0.png
#   inflating: images/images/CHNCXR_0283_0.png
#   inflating: images/images/CHNCXR_0284_0.png
#   inflating: images/images/CHNCXR_0285_0.png
#   inflating: images/images/CHNCXR_0286_0.png
#   inflating: images/images/CHNCXR_0287_0.png
#   inflating: images/images/CHNCXR_0288_0.png
#   inflating: images/images/CHNCXR_0289_0.png
#   inflating: images/images/CHNCXR_0290_0.png
#   inflating: images/images/CHNCXR_0291_0.png
#   inflating: images/images/CHNCXR_0292_0.png
#   inflating: images/images/CHNCXR_0293_0.png
#   inflating: images/images/CHNCXR_0294_0.png
#   inflating: images/images/CHNCXR_0295_0.png
#   inflating: images/images/CHNCXR_0296_0.png
#   inflating: images/images/CHNCXR_0297_0.png
#   inflating: images/images/CHNCXR_0298_0.png
#   inflating: images/images/CHNCXR_0299_0.png
#   inflating: images/images/CHNCXR_0300_0.png
#   inflating: images/images/CHNCXR_0301_0.png
#   inflating: images/images/CHNCXR_0302_0.png
#   inflating: images/images/CHNCXR_0303_0.png
#   inflating: images/images/CHNCXR_0304_0.png
#   inflating: images/images/CHNCXR_0305_0.png
#   inflating: images/images/CHNCXR_0306_0.png
#   inflating: images/images/CHNCXR_0307_0.png
#   inflating: images/images/CHNCXR_0308_0.png
#   inflating: images/images/CHNCXR_0309_0.png
#   inflating: images/images/CHNCXR_0310_0.png
#   inflating: images/images/CHNCXR_0311_0.png
#   inflating: images/images/CHNCXR_0312_0.png
#   inflating: images/images/CHNCXR_0313_0.png
#   inflating: images/images/CHNCXR_0314_0.png
#   inflating: images/images/CHNCXR_0315_0.png
#   inflating: images/images/CHNCXR_0316_0.png
#   inflating: images/images/CHNCXR_0317_0.png
#   inflating: images/images/CHNCXR_0318_0.png
#   inflating: images/images/CHNCXR_0319_0.png
#   inflating: images/images/CHNCXR_0320_0.png
#   inflating: images/images/CHNCXR_0321_0.png
#   inflating: images/images/CHNCXR_0322_0.png
#   inflating: images/images/CHNCXR_0323_0.png
#   inflating: images/images/CHNCXR_0324_0.png
#   inflating: images/images/CHNCXR_0325_0.png
#   inflating: images/images/CHNCXR_0326_0.png
#   inflating: images/images/CHNCXR_0327_1.png
#   inflating: images/images/CHNCXR_0328_1.png
#   inflating: images/images/CHNCXR_0329_1.png
#   inflating: images/images/CHNCXR_0330_1.png
#   inflating: images/images/CHNCXR_0331_1.png
#   inflating: images/images/CHNCXR_0332_1.png
#   inflating: images/images/CHNCXR_0333_1.png
#   inflating: images/images/CHNCXR_0334_1.png
#   inflating: images/images/CHNCXR_0335_1.png
#   inflating: images/images/CHNCXR_0336_1.png
#   inflating: images/images/CHNCXR_0337_1.png
#   inflating: images/images/CHNCXR_0338_1.png
#   inflating: images/images/CHNCXR_0339_1.png
#   inflating: images/images/CHNCXR_0340_1.png
#   inflating: images/images/CHNCXR_0341_1.png
#   inflating: images/images/CHNCXR_0342_1.png
#   inflating: images/images/CHNCXR_0343_1.png
#   inflating: images/images/CHNCXR_0344_1.png
#   inflating: images/images/CHNCXR_0345_1.png
#   inflating: images/images/CHNCXR_0346_1.png
#   inflating: images/images/CHNCXR_0347_1.png
#   inflating: images/images/CHNCXR_0348_1.png
#   inflating: images/images/CHNCXR_0349_1.png
#   inflating: images/images/CHNCXR_0350_1.png
#   inflating: images/images/CHNCXR_0351_1.png
#   inflating: images/images/CHNCXR_0352_1.png
#   inflating: images/images/CHNCXR_0353_1.png
#   inflating: images/images/CHNCXR_0354_1.png
#   inflating: images/images/CHNCXR_0355_1.png
#   inflating: images/images/CHNCXR_0356_1.png
#   inflating: images/images/CHNCXR_0357_1.png
#   inflating: images/images/CHNCXR_0358_1.png
#   inflating: images/images/CHNCXR_0359_1.png
#   inflating: images/images/CHNCXR_0360_1.png
#   inflating: images/images/CHNCXR_0361_1.png
#   inflating: images/images/CHNCXR_0362_1.png
#   inflating: images/images/CHNCXR_0363_1.png
#   inflating: images/images/CHNCXR_0364_1.png
#   inflating: images/images/CHNCXR_0365_1.png
#   inflating: images/images/CHNCXR_0366_1.png
#   inflating: images/images/CHNCXR_0367_1.png
#   inflating: images/images/CHNCXR_0368_1.png
#   inflating: images/images/CHNCXR_0369_1.png
#   inflating: images/images/CHNCXR_0370_1.png
#   inflating: images/images/CHNCXR_0371_1.png
#   inflating: images/images/CHNCXR_0372_1.png
#   inflating: images/images/CHNCXR_0373_1.png
#   inflating: images/images/CHNCXR_0374_1.png
#   inflating: images/images/CHNCXR_0375_1.png
#   inflating: images/images/CHNCXR_0376_1.png
#   inflating: images/images/CHNCXR_0377_1.png
#   inflating: images/images/CHNCXR_0378_1.png
#   inflating: images/images/CHNCXR_0379_1.png
#   inflating: images/images/CHNCXR_0380_1.png
#   inflating: images/images/CHNCXR_0381_1.png
#   inflating: images/images/CHNCXR_0382_1.png
#   inflating: images/images/CHNCXR_0383_1.png
#   inflating: images/images/CHNCXR_0384_1.png
#   inflating: images/images/CHNCXR_0385_1.png
#   inflating: images/images/CHNCXR_0386_1.png
#   inflating: images/images/CHNCXR_0387_1.png
#   inflating: images/images/CHNCXR_0388_1.png
#   inflating: images/images/CHNCXR_0389_1.png
#   inflating: images/images/CHNCXR_0390_1.png
#   inflating: images/images/CHNCXR_0391_1.png
#   inflating: images/images/CHNCXR_0392_1.png
#   inflating: images/images/CHNCXR_0393_1.png
#   inflating: images/images/CHNCXR_0394_1.png
#   inflating: images/images/CHNCXR_0395_1.png
#   inflating: images/images/CHNCXR_0396_1.png
#   inflating: images/images/CHNCXR_0397_1.png
#   inflating: images/images/CHNCXR_0398_1.png
#   inflating: images/images/CHNCXR_0399_1.png
#   inflating: images/images/CHNCXR_0400_1.png
#   inflating: images/images/CHNCXR_0401_1.png
#   inflating: images/images/CHNCXR_0402_1.png
#   inflating: images/images/CHNCXR_0403_1.png
#   inflating: images/images/CHNCXR_0404_1.png
#   inflating: images/images/CHNCXR_0405_1.png
#   inflating: images/images/CHNCXR_0406_1.png
#   inflating: images/images/CHNCXR_0407_1.png
#   inflating: images/images/CHNCXR_0408_1.png
#   inflating: images/images/CHNCXR_0409_1.png
#   inflating: images/images/CHNCXR_0410_1.png
#   inflating: images/images/CHNCXR_0411_1.png
#   inflating: images/images/CHNCXR_0412_1.png
#   inflating: images/images/CHNCXR_0413_1.png
#   inflating: images/images/CHNCXR_0414_1.png
#   inflating: images/images/CHNCXR_0415_1.png
#   inflating: images/images/CHNCXR_0416_1.png
#   inflating: images/images/CHNCXR_0417_1.png
#   inflating: images/images/CHNCXR_0418_1.png
#   inflating: images/images/CHNCXR_0419_1.png
#   inflating: images/images/CHNCXR_0420_1.png
#   inflating: images/images/CHNCXR_0421_1.png
#   inflating: images/images/CHNCXR_0422_1.png
#   inflating: images/images/CHNCXR_0423_1.png
#   inflating: images/images/CHNCXR_0424_1.png
#   inflating: images/images/CHNCXR_0425_1.png
#   inflating: images/images/CHNCXR_0426_1.png
#   inflating: images/images/CHNCXR_0427_1.png
#   inflating: images/images/CHNCXR_0428_1.png
#   inflating: images/images/CHNCXR_0429_1.png
#   inflating: images/images/CHNCXR_0430_1.png
#   inflating: images/images/CHNCXR_0431_1.png
#   inflating: images/images/CHNCXR_0432_1.png
#   inflating: images/images/CHNCXR_0433_1.png
#   inflating: images/images/CHNCXR_0434_1.png
#   inflating: images/images/CHNCXR_0435_1.png
#   inflating: images/images/CHNCXR_0436_1.png
#   inflating: images/images/CHNCXR_0437_1.png
#   inflating: images/images/CHNCXR_0438_1.png
#   inflating: images/images/CHNCXR_0439_1.png
#   inflating: images/images/CHNCXR_0440_1.png
#   inflating: images/images/CHNCXR_0441_1.png
#   inflating: images/images/CHNCXR_0442_1.png
#   inflating: images/images/CHNCXR_0443_1.png
#   inflating: images/images/CHNCXR_0444_1.png
#   inflating: images/images/CHNCXR_0445_1.png
#   inflating: images/images/CHNCXR_0446_1.png
#   inflating: images/images/CHNCXR_0447_1.png
#   inflating: images/images/CHNCXR_0448_1.png
#   inflating: images/images/CHNCXR_0449_1.png
#   inflating: images/images/CHNCXR_0450_1.png
#   inflating: images/images/CHNCXR_0451_1.png
#   inflating: images/images/CHNCXR_0452_1.png
#   inflating: images/images/CHNCXR_0453_1.png
#   inflating: images/images/CHNCXR_0454_1.png
#   inflating: images/images/CHNCXR_0455_1.png
#   inflating: images/images/CHNCXR_0456_1.png
#   inflating: images/images/CHNCXR_0457_1.png
#   inflating: images/images/CHNCXR_0458_1.png
#   inflating: images/images/CHNCXR_0459_1.png
#   inflating: images/images/CHNCXR_0460_1.png
#   inflating: images/images/CHNCXR_0461_1.png
#   inflating: images/images/CHNCXR_0462_1.png
#   inflating: images/images/CHNCXR_0463_1.png
#   inflating: images/images/CHNCXR_0464_1.png
#   inflating: images/images/CHNCXR_0465_1.png
#   inflating: images/images/CHNCXR_0466_1.png
#   inflating: images/images/CHNCXR_0467_1.png
#   inflating: images/images/CHNCXR_0468_1.png
#   inflating: images/images/CHNCXR_0469_1.png
#   inflating: images/images/CHNCXR_0470_1.png
#   inflating: images/images/CHNCXR_0471_1.png
#   inflating: images/images/CHNCXR_0472_1.png
#   inflating: images/images/CHNCXR_0473_1.png
#   inflating: images/images/CHNCXR_0474_1.png
#   inflating: images/images/CHNCXR_0475_1.png
#   inflating: images/images/CHNCXR_0476_1.png
#   inflating: images/images/CHNCXR_0477_1.png
#   inflating: images/images/CHNCXR_0478_1.png
#   inflating: images/images/CHNCXR_0479_1.png
#   inflating: images/images/CHNCXR_0480_1.png
#   inflating: images/images/CHNCXR_0481_1.png
#   inflating: images/images/CHNCXR_0482_1.png
#   inflating: images/images/CHNCXR_0483_1.png
#   inflating: images/images/CHNCXR_0484_1.png
#   inflating: images/images/CHNCXR_0485_1.png
#   inflating: images/images/CHNCXR_0486_1.png
#   inflating: images/images/CHNCXR_0487_1.png
#   inflating: images/images/CHNCXR_0488_1.png
#   inflating: images/images/CHNCXR_0489_1.png
#   inflating: images/images/CHNCXR_0490_1.png
#   inflating: images/images/CHNCXR_0491_1.png
#   inflating: images/images/CHNCXR_0492_1.png
#   inflating: images/images/CHNCXR_0493_1.png
#   inflating: images/images/CHNCXR_0494_1.png
#   inflating: images/images/CHNCXR_0495_1.png
#   inflating: images/images/CHNCXR_0496_1.png
#   inflating: images/images/CHNCXR_0497_1.png
#   inflating: images/images/CHNCXR_0498_1.png
#   inflating: images/images/CHNCXR_0499_1.png
#   inflating: images/images/CHNCXR_0500_1.png
#   inflating: images/images/CHNCXR_0501_1.png
#   inflating: images/images/CHNCXR_0502_1.png
#   inflating: images/images/CHNCXR_0503_1.png
#   inflating: images/images/CHNCXR_0504_1.png
#   inflating: images/images/CHNCXR_0505_1.png
#   inflating: images/images/CHNCXR_0506_1.png
#   inflating: images/images/CHNCXR_0507_1.png
#   inflating: images/images/CHNCXR_0508_1.png
#   inflating: images/images/CHNCXR_0509_1.png
#   inflating: images/images/CHNCXR_0510_1.png
#   inflating: images/images/CHNCXR_0511_1.png
#   inflating: images/images/CHNCXR_0512_1.png
#   inflating: images/images/CHNCXR_0513_1.png
#   inflating: images/images/CHNCXR_0514_1.png
#   inflating: images/images/CHNCXR_0515_1.png
#   inflating: images/images/CHNCXR_0516_1.png
#   inflating: images/images/CHNCXR_0517_1.png
#   inflating: images/images/CHNCXR_0518_1.png
#   inflating: images/images/CHNCXR_0519_1.png
#   inflating: images/images/CHNCXR_0520_1.png
#   inflating: images/images/CHNCXR_0521_1.png
#   inflating: images/images/CHNCXR_0522_1.png
#   inflating: images/images/CHNCXR_0523_1.png
#   inflating: images/images/CHNCXR_0524_1.png
#   inflating: images/images/CHNCXR_0525_1.png
#   inflating: images/images/CHNCXR_0526_1.png
#   inflating: images/images/CHNCXR_0527_1.png
#   inflating: images/images/CHNCXR_0528_1.png
#   inflating: images/images/CHNCXR_0529_1.png
#   inflating: images/images/CHNCXR_0530_1.png
#   inflating: images/images/CHNCXR_0531_1.png
#   inflating: images/images/CHNCXR_0532_1.png
#   inflating: images/images/CHNCXR_0533_1.png
#   inflating: images/images/CHNCXR_0534_1.png
#   inflating: images/images/CHNCXR_0535_1.png
#   inflating: images/images/CHNCXR_0536_1.png
#   inflating: images/images/CHNCXR_0537_1.png
#   inflating: images/images/CHNCXR_0538_1.png
#   inflating: images/images/CHNCXR_0539_1.png
#   inflating: images/images/CHNCXR_0540_1.png
#   inflating: images/images/CHNCXR_0541_1.png
#   inflating: images/images/CHNCXR_0542_1.png
#   inflating: images/images/CHNCXR_0543_1.png
#   inflating: images/images/CHNCXR_0544_1.png
#   inflating: images/images/CHNCXR_0545_1.png
#   inflating: images/images/CHNCXR_0546_1.png
#   inflating: images/images/CHNCXR_0547_1.png
#   inflating: images/images/CHNCXR_0548_1.png
#   inflating: images/images/CHNCXR_0549_1.png
#   inflating: images/images/CHNCXR_0550_1.png
#   inflating: images/images/CHNCXR_0551_1.png
#   inflating: images/images/CHNCXR_0552_1.png
#   inflating: images/images/CHNCXR_0553_1.png
#   inflating: images/images/CHNCXR_0554_1.png
#   inflating: images/images/CHNCXR_0555_1.png
#   inflating: images/images/CHNCXR_0556_1.png
#   inflating: images/images/CHNCXR_0557_1.png
#   inflating: images/images/CHNCXR_0558_1.png
#   inflating: images/images/CHNCXR_0559_1.png
#   inflating: images/images/CHNCXR_0560_1.png
#   inflating: images/images/CHNCXR_0561_1.png
#   inflating: images/images/CHNCXR_0562_1.png
#   inflating: images/images/CHNCXR_0563_1.png
#   inflating: images/images/CHNCXR_0564_1.png
#   inflating: images/images/CHNCXR_0565_1.png
#   inflating: images/images/CHNCXR_0566_1.png
#   inflating: images/images/CHNCXR_0567_1.png
#   inflating: images/images/CHNCXR_0568_1.png
#   inflating: images/images/CHNCXR_0569_1.png
#   inflating: images/images/CHNCXR_0570_1.png
#   inflating: images/images/CHNCXR_0571_1.png
#   inflating: images/images/CHNCXR_0572_1.png
#   inflating: images/images/CHNCXR_0573_1.png
#   inflating: images/images/CHNCXR_0574_1.png
#   inflating: images/images/CHNCXR_0575_1.png
#   inflating: images/images/CHNCXR_0576_1.png
#   inflating: images/images/CHNCXR_0577_1.png
#   inflating: images/images/CHNCXR_0578_1.png
#   inflating: images/images/CHNCXR_0579_1.png
#   inflating: images/images/CHNCXR_0580_1.png
#   inflating: images/images/CHNCXR_0581_1.png
#   inflating: images/images/CHNCXR_0582_1.png
#   inflating: images/images/CHNCXR_0583_1.png
#   inflating: images/images/CHNCXR_0584_1.png
#   inflating: images/images/CHNCXR_0585_1.png
#   inflating: images/images/CHNCXR_0586_1.png
#   inflating: images/images/CHNCXR_0587_1.png
#   inflating: images/images/CHNCXR_0588_1.png
#   inflating: images/images/CHNCXR_0589_1.png
#   inflating: images/images/CHNCXR_0590_1.png
#   inflating: images/images/CHNCXR_0591_1.png
#   inflating: images/images/CHNCXR_0592_1.png
#   inflating: images/images/CHNCXR_0593_1.png
#   inflating: images/images/CHNCXR_0594_1.png
#   inflating: images/images/CHNCXR_0595_1.png
#   inflating: images/images/CHNCXR_0596_1.png
#   inflating: images/images/CHNCXR_0597_1.png
#   inflating: images/images/CHNCXR_0598_1.png
#   inflating: images/images/CHNCXR_0599_1.png
#   inflating: images/images/CHNCXR_0600_1.png
#   inflating: images/images/CHNCXR_0601_1.png
#   inflating: images/images/CHNCXR_0602_1.png
#   inflating: images/images/CHNCXR_0603_1.png
#   inflating: images/images/CHNCXR_0604_1.png
#   inflating: images/images/CHNCXR_0605_1.png
#   inflating: images/images/CHNCXR_0606_1.png
#   inflating: images/images/CHNCXR_0607_1.png
#   inflating: images/images/CHNCXR_0608_1.png
#   inflating: images/images/CHNCXR_0609_1.png
#   inflating: images/images/CHNCXR_0610_1.png
#   inflating: images/images/CHNCXR_0611_1.png
#   inflating: images/images/CHNCXR_0612_1.png
#   inflating: images/images/CHNCXR_0613_1.png
#   inflating: images/images/CHNCXR_0614_1.png
#   inflating: images/images/CHNCXR_0615_1.png
#   inflating: images/images/CHNCXR_0616_1.png
#   inflating: images/images/CHNCXR_0617_1.png
#   inflating: images/images/CHNCXR_0618_1.png
#   inflating: images/images/CHNCXR_0619_1.png
#   inflating: images/images/CHNCXR_0620_1.png
#   inflating: images/images/CHNCXR_0621_1.png
#   inflating: images/images/CHNCXR_0622_1.png
#   inflating: images/images/CHNCXR_0623_1.png
#   inflating: images/images/CHNCXR_0624_1.png
#   inflating: images/images/CHNCXR_0625_1.png
#   inflating: images/images/CHNCXR_0626_1.png
#   inflating: images/images/CHNCXR_0627_1.png
#   inflating: images/images/CHNCXR_0628_1.png
#   inflating: images/images/CHNCXR_0629_1.png
#   inflating: images/images/CHNCXR_0630_1.png
#   inflating: images/images/CHNCXR_0631_1.png
#   inflating: images/images/CHNCXR_0632_1.png
#   inflating: images/images/CHNCXR_0633_1.png
#   inflating: images/images/CHNCXR_0634_1.png
#   inflating: images/images/CHNCXR_0635_1.png
#   inflating: images/images/CHNCXR_0636_1.png
#   inflating: images/images/CHNCXR_0637_1.png
#   inflating: images/images/CHNCXR_0638_1.png
#   inflating: images/images/CHNCXR_0639_1.png
#   inflating: images/images/CHNCXR_0640_1.png
#   inflating: images/images/CHNCXR_0641_1.png
#   inflating: images/images/CHNCXR_0642_1.png
#   inflating: images/images/CHNCXR_0643_1.png
#   inflating: images/images/CHNCXR_0644_1.png
#   inflating: images/images/CHNCXR_0645_1.png
#   inflating: images/images/CHNCXR_0646_1.png
#   inflating: images/images/CHNCXR_0647_1.png
#   inflating: images/images/CHNCXR_0648_1.png
#   inflating: images/images/CHNCXR_0649_1.png
#   inflating: images/images/CHNCXR_0650_1.png
#   inflating: images/images/CHNCXR_0651_1.png
#   inflating: images/images/CHNCXR_0652_1.png
#   inflating: images/images/CHNCXR_0653_1.png
#   inflating: images/images/CHNCXR_0654_1.png
#   inflating: images/images/CHNCXR_0655_1.png
#   inflating: images/images/CHNCXR_0656_1.png
#   inflating: images/images/CHNCXR_0657_1.png
#   inflating: images/images/CHNCXR_0658_1.png
#   inflating: images/images/CHNCXR_0659_1.png
#   inflating: images/images/CHNCXR_0660_1.png
#   inflating: images/images/CHNCXR_0661_1.png
#   inflating: images/images/CHNCXR_0662_1.png
#   inflating: shenzhen_metadata.csv

# %%
# !head -n 5 shenzhen_metadata.csv
# Out:
# study_id,sex,age,findings
# CHNCXR_0001_0.png,Male,45,normal
# CHNCXR_0002_0.png,Male,63,normal
# CHNCXR_0003_0.png,Female,48,normal
# CHNCXR_0004_0.png,Male,58,normal

# %%
import os
import cv2
from google.colab.patches import cv2_imshow

import numpy as np
import matplotlib.pyplot as plt

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import Input, Model, Sequential
from tensorflow.keras import models, layers, optimizers
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.layers import Dense, Flatten, Dropout, MaxPooling2D, Conv2D
from tensorflow.keras.preprocessing import image
from keras.utils.vis_utils import plot_model
from keras.models import load_model

from sklearn.metrics import classification_report, confusion_matrix
from sklearn.model_selection import train_test_split

import pandas as pd

# %%
df = pd.read_csv('shenzhen_metadata.csv')

df['age'] = np.where(df['age'].between(0, 14), 0, df['age'])
df['age'] = np.where(df['age'].between(15, 27), 1, df['age'])
df['age'] = np.where(df['age'].between(28, 44), 2, df['age'])
df['age'] = np.where(df['age'].between(45, 59), 3, df['age'])
df['age'] = np.where(df['age'].between(60, 180), 4, df['age'])
df['findings'] = np.where(df['findings'].isin(['normal']), df['findings'], 'TB')
df['findings'].value_counts()
# Out:
# TB        336
# normal    326
# Name: findings, dtype: int64

# %%
df['labels'] = df['findings'].map({"normal": 0, "TB": 1})
df['sex_label'] = df['sex'].map({"Male": 0, "Female": 1})
df
# Out:
#               study_id     sex  age findings  labels  sex_label
# 0    CHNCXR_0001_0.png    Male    3   normal       0          0
# 1    CHNCXR_0002_0.png    Male    4   normal       0          0
# 2    CHNCXR_0003_0.png  Female    3   normal       0          1
# 3    CHNCXR_0004_0.png    Male    3   normal       0          0
# 4    CHNCXR_0005_0.png    Male    2   normal       0          0
# ..                 ...     ...  ...      ...     ...        ...
# 657  CHNCXR_0658_1.png    Male    2       TB       1          0
# 658  CHNCXR_0659_1.png    Male    2       TB       1          0
# 659  CHNCXR_0660_1.png    Male    3       TB       1          0
# 660  CHNCXR_0661_1.png    Male    1       TB       1          0
# 661  CHNCXR_0662_1.png    Male    2       TB       1          0
#
# [662 rows x 6 columns]

# %%
image_path = '/content/images/images'
model_path = '/content/TB_Model'
w,h = 128, 128

# %%
training_df = df[['study_id', 'labels']].copy()
x = training_df['study_id']
y = training_df['labels']

# %%
#Creating Dataset from raw data
x_img = []
y_labels = []
for id in range (0, len(x)):
  if id%75==0: 
    print('filename: '+x[id])
    print('label: ', y[id], ', verbose: ', df['findings'][id])
  
  image_path = os.path.join('/content/images/images/', x[id])
  img = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
  img = cv2.resize(img, (224, 224), interpolation=cv2.INTER_AREA)
  clahe = cv2.createCLAHE(clipLimit=0.5, tileGridSize=(8,8))
  hist_equal = cv2.equalizeHist(img)
  if id==420:
    base = img
    equalized = cv2.equalizeHist(base)
    clahed = clahe.apply(base)
  x_img.append(hist_equal)
  y_labels.append(y[id])
print("Number of x_img: ", len(x_img))
# Out:
# filename: CHNCXR_0001_0.png
# label:  0 , verbose:  normal
# filename: CHNCXR_0076_0.png
# label:  0 , verbose:  normal
# filename: CHNCXR_0151_0.png
# label:  0 , verbose:  normal
# filename: CHNCXR_0226_0.png
# label:  0 , verbose:  normal
# filename: CHNCXR_0301_0.png
# label:  0 , verbose:  normal
# filename: CHNCXR_0376_1.png
# label:  1 , verbose:  TB
# filename: CHNCXR_0451_1.png
# label:  1 , verbose:  TB
# filename: CHNCXR_0526_1.png
# label:  1 , verbose:  TB
# filename: CHNCXR_0601_1.png
# label:  1 , verbose:  TB
# Number of x_img:  662

# %%
x_img_arr = np.array(x_img)
y_labels_arr = np.array(y_labels)

# %%
fig, axis = plt.subplots(2, 3, figsize=(8,8))
plt.rc('image', cmap='gray')
#Display image
axis[0][0].imshow(base)
axis[0][0].set_title("Origin Image")
axis[0][0].set_axis_off()
axis[0][1].imshow(clahed)
axis[0][1].set_title("CLAHE")
axis[0][1].set_axis_off()
axis[0][2].imshow(equalized)
axis[0][2].set_title("Histogram Equalization")
axis[0][2].set_axis_off()
#Display Histogram
axis[1][0].hist(base.ravel(), bins=256, histtype='step')
cdf1 = axis[1][0].twinx()
cdf1.set_axis_off()
cdf1.hist(img.ravel(), bins=256, histtype='step', cumulative=True, color='r')
axis[1][1].hist(clahed.ravel(), bins=256, histtype='step')
cdf2 = axis[1][1].twinx()
cdf2.set_axis_off()
cdf2.hist(clahed.ravel(), bins=256, histtype='step', cumulative=True, color='r')
axis[1][2].hist(equalized.ravel(), bins=256, histtype='step')
cdf3 = axis[1][2].twinx()
cdf3.hist(equalized.ravel(), bins=256, histtype='step', cumulative=True, color='r')
cdf3.set_axis_off()
fig.tight_layout()
print("Difference between image enhancement method")
# Out:
# Difference between image enhancement method

# %%
import random
from time import time
random.seed(time())
seed = random.randint(1,200)
x_train, x_test, y_train, y_test = train_test_split(x_img_arr, y_labels_arr,
                                                    test_size=0.2,
                                                    random_state=seed,
                                                    stratify=y_labels_arr)
print("Total images in Validation: " + str(len(x_test)))
print("Total images used for Training: " + str(len(x_train)))
# Out:
# Total images in Validation: 133
# Total images used for Training: 529

# %%
plt.figure(figsize=(10, 10))
offset = seed
print('0 is Normal\n1 is Tuberculosis')
for i in range(6):
  ax = plt.subplot(2, 3, i + 1)
  plt.imshow(x_train[i+offset].astype("uint8"), cmap=plt.cm.gray)
  plt.title("Labels:{} ".format(y_train[i+offset]))
  plt.axis("off")
plt.tight_layout()
# Out:
# 0 is Normal
# 1 is Tuberculosis

# %%
#Expand Dimension to 4D tensor
x_train = np.expand_dims(x_train, axis = -1)
y_train = np.expand_dims(y_train, axis = -1)
x_test = np.expand_dims(x_test, axis = -1)
y_test = np.expand_dims(y_test, axis = -1)
print("Training data format: ", x_train.shape)
print("Validation data format: ", x_test.shape)
# Out:
# Training data format:  (529, 224, 224, 1)
# Validation data format:  (133, 224, 224, 1)

# %%
#CTRL F10 FROM HERE TO RETRAIN EVERYTHING
#ONLY UNCOMMENT BELOW LINE FOR RETRAINING PURPOSE, AFTER THAT RE-COMMENT THIS LINE IMMEDIATELY
#keras.backend.clear_session()

# %%
model_path1 = '/content/Model_checkpoint/'
model_checkpoint = ModelCheckpoint(filepath=model_path1, save_best_only=True)
#Reduce overfitting by monitoring on validation accuracy metric
early_stopping = EarlyStopping(monitor='val_acc',
                               min_delta=0,
                               patience=7,
                               verbose=1,
                               mode='auto',
                               restore_best_weights=True)

# %%
def image_model():
  input_shape = Input(shape=(224,224,1))
  #Paralel Feature extraction
  #Standard route
  block1 = Conv2D(16, (3,3), padding='same', activation='relu')(input_shape)
  block1 = Conv2D(16, (3,3), padding='same', activation='relu')(block1)
  block1 = MaxPooling2D(pool_size=(2,2), strides=(2,2))(block1)
  block1 = Conv2D(32, (3,3), padding='same', activation='relu')(block1)
  block1 = Conv2D(32, (3,3), padding='same', activation='relu')(block1)
  block1 = MaxPooling2D(pool_size=(2,2), strides=(2,2))(block1)
  #Detailed route
  block2 = Conv2D(32, (3,3), padding='same', activation='relu')(input_shape)
  block2 = Conv2D(64, (3,3), padding='same', activation='relu')(block2)
  block2 = MaxPooling2D(pool_size=4, padding='same', strides=2)(block2)
  block2 = Conv2D(64, (3,3), padding='same', activation='relu')(block2)
  block2 = Conv2D(32, (3,3), padding='same', activation='relu')(block2)
  block2 = MaxPooling2D(pool_size=4, padding='same', strides=2)(block2)
  #Generalize route
  block3 = Conv2D(16, (7,7), padding='same', activation='relu')(input_shape)
  block3 = Conv2D(16, (7,7), padding='same', activation='relu')(block3)
  block3 = MaxPooling2D(pool_size=(5,5), padding='same', strides=(2,2))(block3)
  block3 = Conv2D(32, (7,7), padding='same', activation='relu')(block3)
  block3 = Conv2D(32, (7,7), padding='same', activation='relu')(block3)
  block3 = MaxPooling2D(pool_size=(5,5), padding='same', strides=(2,2))(block3)

  #Fully connected layer
  merged = keras.layers.concatenate([block1, block2, block3], axis=1)
  merged = Flatten()(merged)

  hidden1 = Dense(256, activation='relu')(merged)
  hidden1 = Dropout(0.3)(hidden1)
  hidden1 = Dense(128, activation='relu')(merged)
  hidden1 = Dropout(0.2)(hidden1)
  hidden1 = Dense(64, activation='relu')(merged)
  hidden1 = Dropout(0.1)(hidden1)
  hidden1 = Dense(32, activation='relu')(merged)
  hidden1 = Dropout(0.05)(hidden1)
  predict = Dense(1, activation='sigmoid', name='Predict')(hidden1)
  
  model = Model(input_shape, predict)
  return model

# %%
#Momentum Learning rate
initial_learning_rate = 0.0001
lr_schedule = keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate, decay_steps=100000, decay_rate=0.9, staircase=True)

# %%
model = image_model()
plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=False)

# %%
model.compile(optimizer=optimizers.Adam(learning_rate=lr_schedule),
              loss='binary_crossentropy',
              metrics=['acc'])

# %%
if retrain:
  history = model.fit(x_train, y_train, 
                      epochs=50, 
                      batch_size=32, 
                      validation_data=(x_test, y_test),
                      verbose=1,
                      callbacks=[early_stopping, model_checkpoint])
else: 
  #Wait for unzipping progress complete. This can be very long since the model is about 110MBs
  while (not os.path.exists(os.path.join('/content/TB_Model', 'saved_model.pb'))):
    pass
  model = load_model(model_path, compile=True)
# Out:
# Epoch 1/50
# 17/17 [==============================] - 11s 551ms/step - loss: 26.6874 - acc: 0.5274 - val_loss: 0.6614 - val_acc: 0.6241
# INFO:tensorflow:Assets written to: /content/Model_checkpoint/assets
# Epoch 2/50
# 17/17 [==============================] - 9s 533ms/step - loss: 0.7560 - acc: 0.6389 - val_loss: 0.5890 - val_acc: 0.6992
# INFO:tensorflow:Assets written to: /content/Model_checkpoint/assets
# Epoch 3/50
# 17/17 [==============================] - 9s 532ms/step - loss: 0.4914 - acc: 0.7864 - val_loss: 0.6059 - val_acc: 0.7970
# Epoch 4/50
# 17/17 [==============================] - 9s 530ms/step - loss: 0.5020 - acc: 0.8053 - val_loss: 0.5365 - val_acc: 0.7594
# INFO:tensorflow:Assets written to: /content/Model_checkpoint/assets
# Epoch 5/50
# 17/17 [==============================] - 9s 531ms/step - loss: 0.4089 - acc: 0.8261 - val_loss: 0.5526 - val_acc: 0.7895
# Epoch 6/50
# 17/17 [==============================] - 9s 533ms/step - loss: 0.4087 - acc: 0.8223 - val_loss: 0.4992 - val_acc: 0.7970
# INFO:tensorflow:Assets written to: /content/Model_checkpoint/assets
# Epoch 7/50
# 17/17 [==============================] - 9s 530ms/step - loss: 0.3826 - acc: 0.8526 - val_loss: 0.6438 - val_acc: 0.7970
# Epoch 8/50
# 17/17 [==============================] - 9s 531ms/step - loss: 0.3156 - acc: 0.8620 - val_loss: 0.5345 - val_acc: 0.7895
# Epoch 9/50
# 17/17 [==============================] - 9s 532ms/step - loss: 0.2440 - acc: 0.8752 - val_loss: 0.4931 - val_acc: 0.8045
# INFO:tensorflow:Assets written to: /content/Model_checkpoint/assets
# Epoch 10/50
# 17/17 [==============================] - 9s 534ms/step - loss: 0.1927 - acc: 0.8941 - val_loss: 0.6794 - val_acc: 0.7820
# Epoch 11/50
# 17/17 [==============================] - 9s 533ms/step - loss: 0.2996 - acc: 0.8866 - val_loss: 0.6064 - val_acc: 0.7970
# Epoch 12/50
# 17/17 [==============================] - 9s 533ms/step - loss: 0.2023 - acc: 0.9130 - val_loss: 0.5995 - val_acc: 0.7594
# Epoch 13/50
# 17/17 [==============================] - 9s 534ms/step - loss: 0.1690 - acc: 0.9149 - val_loss: 0.6214 - val_acc: 0.7895
# Epoch 14/50
# 17/17 [==============================] - 9s 536ms/step - loss: 0.2155 - acc: 0.9093 - val_loss: 0.5001 - val_acc: 0.8120
# Epoch 15/50
# 17/17 [==============================] - 9s 534ms/step - loss: 0.1260 - acc: 0.9433 - val_loss: 0.5407 - val_acc: 0.7744
# Epoch 16/50
# 17/17 [==============================] - 9s 535ms/step - loss: 0.1546 - acc: 0.9263 - val_loss: 0.8564 - val_acc: 0.7444
# Epoch 17/50
# 17/17 [==============================] - 9s 533ms/step - loss: 0.1363 - acc: 0.9244 - val_loss: 0.6486 - val_acc: 0.7744
# Epoch 18/50
# 17/17 [==============================] - 9s 534ms/step - loss: 0.0692 - acc: 0.9565 - val_loss: 0.6726 - val_acc: 0.7744
# Epoch 19/50
# 17/17 [==============================] - 9s 533ms/step - loss: 0.0639 - acc: 0.9565 - val_loss: 0.8370 - val_acc: 0.7444
# Epoch 20/50
# 17/17 [==============================] - 9s 533ms/step - loss: 0.0808 - acc: 0.9490 - val_loss: 0.7624 - val_acc: 0.7669
# Epoch 21/50
# 17/17 [==============================] - 9s 533ms/step - loss: 0.0745 - acc: 0.9490 - val_loss: 0.7390 - val_acc: 0.7594
# Restoring model weights from the end of the best epoch.
# Epoch 00021: early stopping

# %%
if retrain:
  fig, ax = plt.subplots(1, 2, figsize=(20, 3))
  ax = ax.ravel()
  for i, metric in enumerate(['acc', 'loss']):
      ax[i].plot(model.history.history[metric])
      ax[i].plot(model.history.history["val_" + metric])
      ax[i].set_title("Model {}".format(metric))
      ax[i].set_xlabel("epochs")
      ax[i].set_ylabel(metric)
      ax[i].legend(["train", "validation"])

# %%
prediction = model.predict(x_test)

# %%
plt.figure(figsize=(20, 15))
for i in range(24):
  ax = plt.subplot(4, 6, i + 1)
  plt.imshow(np.squeeze(x_test[i]).astype("uint8"), cmap=plt.cm.gray)
  plt.title("Truth: {}\n Predict: {}".format(y_test[i], prediction[i].round(2)))
  plt.axis("off")

# %%
count = 0
validation_sample = len(y_test)
print("Total validation sample: ", validation_sample)
for i in range(validation_sample):
  if prediction.round(0).astype(np.int)[i]== y_test[i]:
    count += 1
print("Correct prediction:      " ,count)
# Out:
# Total validation sample:  133
# Correct prediction:       108

# %%
conf_matrix = confusion_matrix(y_true=y_test, y_pred=prediction.round(0).astype(np.int))
fig, ax = plt.subplots(figsize=(5,5))
ax.matshow(conf_matrix, cmap=plt.cm.YlGn, alpha=0.68)
for i in range(conf_matrix.shape[0]):
    for j in range(conf_matrix.shape[1]):
        ax.text(x=j, y=i,s=conf_matrix[i, j], va='center', ha='center', size='xx-large')
 
plt.xlabel('Predictions', fontsize=18)
plt.ylabel('Actuals', fontsize=18)
plt.title('Confusion Matrix', fontsize=18)
plt.show()

# %%
print(classification_report(y_true=y_test, y_pred=prediction.round(0).astype(np.int)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.79      0.85      0.81        65
#            1       0.84      0.78      0.81        68
#
#     accuracy                           0.81       133
#    macro avg       0.81      0.81      0.81       133
# weighted avg       0.81      0.81      0.81       133

# %%
#Prediction for entire dataset
y_labels_pred = model.predict(x_img_arr)

# %%
y_labels_pred = y_labels_pred.round(0).astype(np.int)
count = 0
population = len(y_labels_pred)
print("Dataset population: ", population)
for i in range(population):
  if y_labels_pred[i] == y_labels_arr[i]:
    count += 1
print("Correct percentage: {:.2f}".format((count/population)*100))
# Out:
# Dataset population:  662
# Correct percentage: 93.20

# %%
#Make new dataFrame with y_labels_pred
df['prediction'] = y_labels_pred.squeeze(axis=-1)
train_df = df[['age', 'sex_label', 'prediction', 'labels']].copy()
print(train_df)
label_df = train_df.pop('labels')
train_df = np.array(train_df)
label_df = np.array(label_df)
x_train_df, x_test_df, y_train_df, y_test_df = train_test_split(train_df, label_df,
                                                    test_size=0.2,
                                                    random_state=seed,
                                                    stratify=label_df)
x_train_df
# Out:
#      age  sex_label  prediction  labels
# 0      3          0           0       0
# 1      4          0           0       0
# 2      3          1           0       0
# 3      3          0           0       0
# 4      2          0           0       0
# ..   ...        ...         ...     ...
# 657    2          0           1       1
# 658    2          0           1       1
# 659    3          0           1       1
# 660    1          0           1       1
# 661    2          0           1       1
#
# [662 rows x 4 columns]
# array([[1, 0, 0],
#        [2, 0, 1],
#        [2, 0, 1],
#        ...,
#        [2, 0, 1],
#        [1, 1, 1],
#        [1, 0, 0]])

# %%
def ANN():
  model = Sequential()
  model.add(Dense(256, activation='relu'))
  model.add(Dropout(0.3))
  model.add(Dense(128, activation='relu'))
  model.add(Dropout(0.2))
  model.add(Dense(32, activation='relu'))
  model.add(Dropout(0.1))
  model.add(Dense(1, activation='sigmoid'))
  return model

# %%
#!mkdir -p '/content/final_model_checkpoint'
#model2_path = '/content/final_model_checkpoint'
#model2_checkpoint = ModelCheckpoint(filepath=model_path, save_best_only=True)
#early_stopping = EarlyStopping(monitor='val_loss',
#                               min_delta=0,
#                               patience=10,
#                               verbose=1,
#                               mode='auto',
#                              restore_best_weights=True)

# %%
model2 = ANN()
model2.compile(optimizer=keras.optimizers.Adam(learning_rate=lr_schedule),
                 loss='binary_crossentropy',
                 metrics=['acc'])
history = model2.fit(x_train_df, y_train_df, 
                epochs=70, 
                batch_size=32,
                validation_data=(x_test_df, y_test_df),
                callbacks=[early_stopping, model2_checkpoint])
# Out:
# Epoch 1/70
# 17/17 [==============================] - 1s 16ms/step - loss: 0.6738 - acc: 0.6238 - val_loss: 0.6759 - val_acc: 0.5188
# Epoch 2/70
# 17/17 [==============================] - 0s 6ms/step - loss: 0.6648 - acc: 0.6446 - val_loss: 0.6630 - val_acc: 0.5188
# Epoch 3/70
# 17/17 [==============================] - 0s 6ms/step - loss: 0.6412 - acc: 0.7391 - val_loss: 0.6459 - val_acc: 0.7293
# Epoch 4/70
# 17/17 [==============================] - 0s 6ms/step - loss: 0.6225 - acc: 0.7996 - val_loss: 0.6273 - val_acc: 0.8120
# Epoch 5/70
# 17/17 [==============================] - 0s 6ms/step - loss: 0.5968 - acc: 0.8526 - val_loss: 0.6081 - val_acc: 0.8120
# Epoch 6/70
# 17/17 [==============================] - 0s 6ms/step - loss: 0.5721 - acc: 0.8828 - val_loss: 0.5885 - val_acc: 0.8120
# Epoch 7/70
# 17/17 [==============================] - 0s 6ms/step - loss: 0.5480 - acc: 0.8960 - val_loss: 0.5681 - val_acc: 0.8120
# Epoch 8/70
# 17/17 [==============================] - 0s 6ms/step - loss: 0.5221 - acc: 0.8998 - val_loss: 0.5479 - val_acc: 0.8120
# Epoch 9/70
# 17/17 [==============================] - 0s 6ms/step - loss: 0.4737 - acc: 0.9452 - val_loss: 0.5299 - val_acc: 0.8120
# Epoch 10/70
# 17/17 [==============================] - 0s 7ms/step - loss: 0.4368 - acc: 0.9414 - val_loss: 0.5108 - val_acc: 0.8120
# Epoch 11/70
# 17/17 [==============================] - 0s 6ms/step - loss: 0.4073 - acc: 0.9471 - val_loss: 0.4976 - val_acc: 0.8120
# Restoring model weights from the end of the best epoch.
# INFO:tensorflow:Assets written to: /content/TB_Model/assets
# Epoch 00011: early stopping

# %%
fig, ax = plt.subplots(1, 2, figsize=(20, 3))
ax = ax.ravel()
for i, metric in enumerate(['acc', 'loss']):
    ax[i].plot(model2.history.history[metric])
    ax[i].plot(model2.history.history["val_" + metric])
    ax[i].set_title("Model {}".format(metric))
    ax[i].set_xlabel("epochs")
    ax[i].set_ylabel(metric)
    ax[i].legend(["train", "validation"])

# %%
prediction2 = model2.predict(x_test_df)

# %%
conf_matrix = confusion_matrix(y_true=y_test_df, y_pred=prediction2.round(0).astype(np.int))
fig, ax = plt.subplots(figsize=(5,5))
ax.matshow(conf_matrix, cmap=plt.cm.RdPu, alpha=0.68)
for i in range(conf_matrix.shape[0]):
    for j in range(conf_matrix.shape[1]):
        ax.text(x=j, y=i,s=conf_matrix[i, j], va='center', ha='center', size='xx-large')
 
plt.xlabel('Predictions', fontsize=18)
plt.ylabel('Actuals', fontsize=18)
plt.title('Confusion Matrix', fontsize=18)
plt.show()

# %%
print(classification_report(y_true=y_test_df, y_pred=prediction2.round(0).astype(np.int)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.79      0.85      0.81        65
#            1       0.84      0.78      0.81        68
#
#     accuracy                           0.81       133
#    macro avg       0.81      0.81      0.81       133
# weighted avg       0.81      0.81      0.81       133
